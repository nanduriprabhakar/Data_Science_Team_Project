# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as plt2
# %matplotlib inline

# %%
raw_data_f1=pd.read_csv('File_1_copy.csv',index_col='time')
input_and_output_f1=pd.DataFrame(columns=['leaf1','leaf2','leaf3','leaf4','leaf5','leaf6','leaf7','leaf8','spine1','spine2','spine3','spine4'],index=raw_data_f1.index)
input_and_output_f1['leaf1']=raw_data_f1['leaf1 input packet rate']+raw_data_f1['leaf1 output packet rate']
input_and_output_f1['leaf2']=raw_data_f1['leaf2 input packet rate']+raw_data_f1['leaf2 output packet rate']
input_and_output_f1['leaf3']=raw_data_f1['leaf3 input packet rate']+raw_data_f1['leaf3 output packet rate']
input_and_output_f1['leaf4']=raw_data_f1['leaf4 input packet rate']+raw_data_f1['leaf4 output packet rate']
input_and_output_f1['leaf5']=raw_data_f1['leaf5 input packet rate']+raw_data_f1['leaf5 output packet rate']
input_and_output_f1['leaf6']=raw_data_f1['leaf6 input packet rate']+raw_data_f1['leaf6 output packet rate']
input_and_output_f1['leaf7']=raw_data_f1['leaf7 input packet rate']+raw_data_f1['leaf7 output packet rate']
input_and_output_f1['leaf8']=raw_data_f1['leaf8 input packet rate']+raw_data_f1['leaf8 output packet rate']
input_and_output_f1['spine1']=raw_data_f1['spine1 input packet rate']+raw_data_f1['spine1 output packet rate']
input_and_output_f1['spine2']=raw_data_f1['spine2 input packet rate']+raw_data_f1['spine2 output packet rate']
input_and_output_f1['spine3']=raw_data_f1['spine3 input packet rate']+raw_data_f1['spine3 output packet rate']
input_and_output_f1['spine4']=raw_data_f1['spine4 input packet rate']+raw_data_f1['spine4 output packet rate']
raw_data_f2=pd.read_csv('File_2_copy.csv',index_col='time')
input_and_output_f2=pd.DataFrame(columns=['leaf1','leaf2','leaf3','leaf4','leaf5','leaf6','leaf7','leaf8','spine1','spine2','spine3','spine4'],index=raw_data_f2.index)
input_and_output_f2['leaf1']=raw_data_f2['leaf1 input packet rate']+raw_data_f2['leaf1 output packet rate']
input_and_output_f2['leaf2']=raw_data_f2['leaf2 input packet rate']+raw_data_f2['leaf2 output packet rate']
input_and_output_f2['leaf3']=raw_data_f2['leaf3 input packet rate']+raw_data_f2['leaf3 output packet rate']
input_and_output_f2['leaf4']=raw_data_f2['leaf4 input packet rate']+raw_data_f2['leaf4 output packet rate']
input_and_output_f2['leaf5']=raw_data_f2['leaf5 input packet rate']+raw_data_f2['leaf5 output packet rate']
input_and_output_f2['leaf6']=raw_data_f2['leaf6 input packet rate']+raw_data_f2['leaf6 output packet rate']
input_and_output_f2['leaf7']=raw_data_f2['leaf7 input packet rate']+raw_data_f2['leaf7 output packet rate']
input_and_output_f2['leaf8']=raw_data_f2['leaf8 input packet rate']+raw_data_f2['leaf8 output packet rate']
input_and_output_f2['spine1']=raw_data_f2['spine1 input packet rate']+raw_data_f2['spine1 output packet rate']
input_and_output_f2['spine2']=raw_data_f2['spine2 input packet rate']+raw_data_f2['spine2 output packet rate']
input_and_output_f2['spine3']=raw_data_f2['spine3 input packet rate']+raw_data_f2['spine3 output packet rate']
input_and_output_f2['spine4']=raw_data_f2['spine4 input packet rate']+raw_data_f2['spine4 output packet rate']
raw_data_f3=pd.read_csv('File_3_copy.csv',index_col='time')
input_and_output_f3=pd.DataFrame(columns=['leaf1','leaf2','leaf3','leaf4','leaf5','leaf6','leaf7','leaf8','spine1','spine2','spine3','spine4'],index=raw_data_f3.index)
input_and_output_f3['leaf1']=raw_data_f3['leaf1 input packet rate']+raw_data_f3['leaf1 output packet rate']
input_and_output_f3['leaf2']=raw_data_f3['leaf2 input packet rate']+raw_data_f3['leaf2 output packet rate']
input_and_output_f3['leaf3']=raw_data_f3['leaf3 input packet rate']+raw_data_f3['leaf3 output packet rate']
input_and_output_f3['leaf4']=raw_data_f3['leaf4 input packet rate']+raw_data_f3['leaf4 output packet rate']
input_and_output_f3['leaf5']=raw_data_f3['leaf5 input packet rate']+raw_data_f3['leaf5 output packet rate']
input_and_output_f3['leaf6']=raw_data_f3['leaf6 input packet rate']+raw_data_f3['leaf6 output packet rate']
input_and_output_f3['leaf7']=raw_data_f3['leaf7 input packet rate']+raw_data_f3['leaf7 output packet rate']
input_and_output_f3['leaf8']=raw_data_f3['leaf8 input packet rate']+raw_data_f3['leaf8 output packet rate']
input_and_output_f3['spine1']=raw_data_f3['spine1 input packet rate']+raw_data_f3['spine1 output packet rate']
input_and_output_f3['spine2']=raw_data_f3['spine2 input packet rate']+raw_data_f3['spine2 output packet rate']
input_and_output_f3['spine3']=raw_data_f3['spine3 input packet rate']+raw_data_f3['spine3 output packet rate']
input_and_output_f3['spine4']=raw_data_f3['spine4 input packet rate']+raw_data_f3['spine4 output packet rate']

# %%
means_for_file1=[0]
for i in input_and_output_f1.columns:
    temp_df=input_and_output_f1[[i]]
    temp_df.plot(temp_df.index,i)
    means_for_file1.append(input_and_output_f1[[i]].mean())

# %%
means_for_file2=[0]
for i in input_and_output_f2.columns:
    temp_df=input_and_output_f2[[i]]
    temp_df.plot(temp_df.index,i)
    means_for_file2.append(input_and_output_f2[[i]].mean())

# %%
means_for_file3=[0]
for i in input_and_output_f3.columns:
    temp_df=input_and_output_f3[[i]]
    temp_df.plot(temp_df.index,i)
    means_for_file3.append(input_and_output_f3[[i]].mean())

# %% [markdown]
# Oberservations from initial data analysis of all the three training files
# 1. File1 - One leaf fails (Leaf6)
# 2. File2 - Normal Operation
# 3. File3 - One Spine fails(Spine2)
#
# We need to take into consideration the considerable amount of falls in both the input and output packet rates to completely determine whether the element has fallen or not. Just by looking at one parameter(say only input packet rate) we can not be completely sure whether that network element has failed or not.[Case of Spine1 in File3]

# %% [markdown]
# ASSUMPTION: Both input packet rate and output packet rate have equal weightage/importance in determining whether the particular network element has failed or not. There is a linear relationship between the percentage increase or decrease of the packet rate data with change in probability of failure.

# %%
## Analysis for File1 w.r.t file2

# %%
input_and_output_f1.describe()
# Out:
#               leaf1         leaf2         leaf3         leaf4         leaf5  \
# count  1.802000e+03  1.820000e+03  1.802000e+03  1.802000e+03  1.802000e+03
# mean   1.716837e+06  1.710543e+06  1.709529e+06  1.496082e+06  1.762710e+06
# std    2.939933e+06  2.970196e+06  3.310401e+06  3.004448e+06  3.445872e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    1.563536e+06  1.395760e+06  8.367650e+05  4.708345e+05  1.195138e+06
# 75%    2.013082e+06  2.020315e+06  1.075724e+06  1.689797e+06  1.995232e+06
# max    1.644718e+07  1.655634e+07  1.654159e+07  1.591406e+07  1.568304e+07
#
#               leaf6         leaf7         leaf8        spine1        spine2  \
# count  1.802000e+03  1.785000e+03  1.802000e+03  1.768000e+03  1.768000e+03
# mean   1.255884e+06  1.862530e+06  1.790514e+06  2.255619e+06  1.486035e+06
# ...

# %%
input_and_output_f2.describe()
# Out:
#               leaf1         leaf2         leaf3         leaf4         leaf5  \
# count  1.870000e+03  1.925000e+03  1.870000e+03  1.904000e+03  1.870000e+03
# mean   1.820541e+06  1.804517e+06  1.776161e+06  1.575988e+06  1.736824e+06
# std    3.090163e+06  3.102839e+06  3.437323e+06  3.146262e+06  3.395235e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    1.629570e+06  1.533975e+06  8.777565e+05  5.530985e+05  1.195739e+06
# 75%    2.121326e+06  2.136920e+06  1.095357e+06  1.752828e+06  1.979494e+06
# max    1.648425e+07  1.654218e+07  1.655550e+07  1.592697e+07  1.497290e+07
#
#               leaf6         leaf7         leaf8        spine1        spine2  \
# count  1.839000e+03  1.882000e+03  1.870000e+03  1.836000e+03  1.870000e+03
# mean   1.663166e+06  1.877366e+06  1.770508e+06  2.339417e+06  1.578541e+06
# ...

# %%
input_and_output_f3.describe()
# Out:
#               leaf1         leaf2         leaf3         leaf4         leaf5  \
# count  1.802000e+03  1.841000e+03  1.802000e+03  1.802000e+03  1.802000e+03
# mean   1.816352e+06  1.816962e+06  1.774374e+06  1.570332e+06  1.747771e+06
# std    3.106115e+06  3.112061e+06  3.360071e+06  3.141333e+06  3.426968e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    1.378661e+06  1.250300e+06  8.106685e+05  1.263770e+05  8.268745e+05
# 75%    2.155534e+06  2.188121e+06  1.259988e+06  1.848913e+06  2.065302e+06
# max    1.671610e+07  1.654957e+07  1.665374e+07  1.591959e+07  1.544942e+07
#
#               leaf6         leaf7         leaf8        spine1        spine2  \
# count  1.797000e+03  1.802000e+03  1.802000e+03  1.768000e+03  1.802000e+03
# mean   1.655143e+06  1.853974e+06  1.776399e+06  2.350396e+06  1.192607e+06
# ...

# %%
means_for_file2
# Out:
# [0, leaf1    1.820541e+06
#  dtype: float64, leaf2    1.804517e+06
#  dtype: float64, leaf3    1.776161e+06
#  dtype: float64, leaf4    1.575988e+06
#  dtype: float64, leaf5    1.736824e+06
#  dtype: float64, leaf6    1.663166e+06
#  dtype: float64, leaf7    1.877366e+06
#  dtype: float64, leaf8    1.770508e+06
#  dtype: float64, spine1    2.339417e+06
#  dtype: float64, spine2    1.578541e+06
#  dtype: float64, spine3    1.626930e+06
#  dtype: float64, spine4    1.485913e+06
#  dtype: float64]

# %%
average_change_between_file1_and_file2=[0]
for i in range(1,13):
    change_percentage = ((means_for_file2[i]-means_for_file1[i])/(means_for_file2[i]))*100
    average_change_between_file1_and_file2.append(change_percentage)

# %%
average_change_between_file1_and_file2
# Out:
# [0, leaf1    5.696311
#  dtype: float64, leaf2    5.207671
#  dtype: float64, leaf3    3.751461
#  dtype: float64, leaf4    5.070171
#  dtype: float64, leaf5   -1.490412
#  dtype: float64, leaf6    24.488346
#  dtype: float64, leaf7    0.790274
#  dtype: float64, leaf8   -1.129945
#  dtype: float64, spine1    3.581988
#  dtype: float64, spine2    5.86028
#  dtype: float64, spine3    4.638093
#  dtype: float64, spine4    6.549715
#  dtype: float64]

# %%
average_change_between_file3_and_file2=[0]
for i in range(1,13):
    change_percentage = ((means_for_file2[i]-means_for_file3[i])/(means_for_file2[i]))*100
    average_change_between_file3_and_file2.append(change_percentage)

# %%
average_change_between_file3_and_file2
# Out:
# [0, leaf1    0.230082
#  dtype: float64, leaf2   -0.689694
#  dtype: float64, leaf3    0.100614
#  dtype: float64, leaf4    0.358886
#  dtype: float64, leaf5   -0.630293
#  dtype: float64, leaf6    0.482384
#  dtype: float64, leaf7    1.245972
#  dtype: float64, leaf8   -0.332688
#  dtype: float64, spine1   -0.469317
#  dtype: float64, spine2    24.448791
#  dtype: float64, spine3   -12.856112
#  dtype: float64, spine4   -11.28722
#  dtype: float64]

# %%
percentage_change_for_file1_leaf1=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_leaf1.append(((means_for_file2[1]-input_and_output_f1.leaf1.loc[i:j].mean())/means_for_file2[1])*100)
            break

# %%
percentage_change_for_file1_leaf2=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_leaf2.append(((means_for_file2[2]-input_and_output_f1.leaf2.loc[i:j].mean())/means_for_file2[2])*100)
            break

# %%
percentage_change_for_file1_leaf3=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_leaf3.append(((means_for_file2[3]-input_and_output_f1.leaf3.loc[i:j].mean())/means_for_file2[3])*100)
            break

# %%
percentage_change_for_file1_leaf4=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_leaf4.append(((means_for_file2[4]-input_and_output_f1.leaf4.loc[i:j].mean())/means_for_file2[4])*100)
            break

# %%
percentage_change_for_file1_leaf5=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_leaf5.append(((means_for_file2[5]-input_and_output_f1.leaf5.loc[i:j].mean())/means_for_file2[5])*100)
            break

# %%
percentage_change_for_file1_leaf6=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_leaf6.append(((means_for_file2[6]-input_and_output_f1.leaf6.loc[i:j].mean())/means_for_file2[6])*100)
            break

# %%
percentage_change_for_file1_leaf7=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_leaf7.append(((means_for_file2[7]-input_and_output_f1.leaf7.loc[i:j].mean())/means_for_file2[7])*100)
            break

# %%
percentage_change_for_file1_leaf8=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_leaf8.append(((means_for_file2[8]-input_and_output_f1.leaf8.loc[i:j].mean())/means_for_file2[8])*100)
            break

# %%
percentage_change_for_file1_spine1=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_spine1.append(((means_for_file2[9]-input_and_output_f1.spine1.loc[i:j].mean())/means_for_file2[9])*100)
            break

# %%
percentage_change_for_file1_spine2=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_spine2.append(((means_for_file2[10]-input_and_output_f1.spine2.loc[i:j].mean())/means_for_file2[10])*100)
            break

# %%
percentage_change_for_file1_spine3=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_spine3.append(((means_for_file2[11]-input_and_output_f1.spine3.loc[i:j].mean())/means_for_file2[11])*100)
            break

# %%
percentage_change_for_file1_spine4=[0]
for i in input_and_output_f1.index[::400]:
    for j in input_and_output_f1.index:
        if j-i > 5000000000:
            percentage_change_for_file1_spine4.append(((means_for_file2[12]-input_and_output_f1.spine4.loc[i:j].mean())/means_for_file2[12])*100)
            break

# %%
percentage_change_for_file1=[percentage_change_for_file1_leaf1,percentage_change_for_file1_leaf2,percentage_change_for_file1_leaf3,percentage_change_for_file1_leaf4,percentage_change_for_file1_leaf5,percentage_change_for_file1_leaf6,percentage_change_for_file1_leaf7,percentage_change_for_file1_leaf8,percentage_change_for_file1_spine1,percentage_change_for_file1_spine2,percentage_change_for_file1_spine3,percentage_change_for_file1_spine4]

# %%
percentage_change_for_file3_leaf1=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_leaf1.append(((means_for_file2[1]-input_and_output_f3.leaf1.loc[i:j].mean())/means_for_file2[1])*100)
            break
percentage_change_for_file3_leaf2=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_leaf2.append(((means_for_file2[2]-input_and_output_f3.leaf2.loc[i:j].mean())/means_for_file2[2])*100)
            break
percentage_change_for_file3_leaf3=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_leaf3.append(((means_for_file2[3]-input_and_output_f3.leaf3.loc[i:j].mean())/means_for_file2[3])*100)
            break
percentage_change_for_file3_leaf4=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_leaf4.append(((means_for_file2[4]-input_and_output_f3.leaf4.loc[i:j].mean())/means_for_file2[4])*100)
            break
percentage_change_for_file3_leaf5=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_leaf5.append(((means_for_file2[5]-input_and_output_f3.leaf5.loc[i:j].mean())/means_for_file2[5])*100)
            break
percentage_change_for_file3_leaf6=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_leaf6.append(((means_for_file2[6]-input_and_output_f3.leaf6.loc[i:j].mean())/means_for_file2[6])*100)
            break
percentage_change_for_file3_leaf7=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_leaf7.append(((means_for_file2[7]-input_and_output_f3.leaf7.loc[i:j].mean())/means_for_file2[7])*100)
            break
percentage_change_for_file3_leaf8=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_leaf8.append(((means_for_file2[8]-input_and_output_f3.leaf8.loc[i:j].mean())/means_for_file2[8])*100)
            break
percentage_change_for_file3_spine1=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_spine1.append(((means_for_file2[9]-input_and_output_f3.spine1.loc[i:j].mean())/means_for_file2[9])*100)
            break
percentage_change_for_file3_spine2=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_spine2.append(((means_for_file2[10]-input_and_output_f3.spine2.loc[i:j].mean())/means_for_file2[10])*100)
            break
percentage_change_for_file3_spine3=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_spine3.append(((means_for_file2[11]-input_and_output_f3.spine3.loc[i:j].mean())/means_for_file2[11])*100)
            break
percentage_change_for_file3_spine4=[0]
for i in input_and_output_f3.index[::400]:
    for j in input_and_output_f3.index:
        if j-i > 5000000000:
            percentage_change_for_file3_spine4.append(((means_for_file2[12]-input_and_output_f3.spine4.loc[i:j].mean())/means_for_file2[12])*100)
            break
percentage_change_for_file3=[percentage_change_for_file3_leaf1,percentage_change_for_file3_leaf2,percentage_change_for_file3_leaf3,percentage_change_for_file3_leaf4,percentage_change_for_file3_leaf5,percentage_change_for_file3_leaf6,percentage_change_for_file3_leaf7,percentage_change_for_file3_leaf8,percentage_change_for_file3_spine1,percentage_change_for_file3_spine2,percentage_change_for_file3_spine3,percentage_change_for_file3_spine4]

# %%
percentage_change_for_file2_leaf1=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_leaf1.append(((means_for_file2[1]-input_and_output_f2.leaf1.loc[i:j].mean())/means_for_file2[1])*100)
            break
percentage_change_for_file2_leaf2=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_leaf2.append(((means_for_file2[2]-input_and_output_f2.leaf2.loc[i:j].mean())/means_for_file2[2])*100)
            break
percentage_change_for_file2_leaf3=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_leaf3.append(((means_for_file2[3]-input_and_output_f2.leaf3.loc[i:j].mean())/means_for_file2[3])*100)
            break
percentage_change_for_file2_leaf4=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_leaf4.append(((means_for_file2[4]-input_and_output_f2.leaf4.loc[i:j].mean())/means_for_file2[4])*100)
            break
percentage_change_for_file2_leaf5=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_leaf5.append(((means_for_file2[5]-input_and_output_f2.leaf5.loc[i:j].mean())/means_for_file2[5])*100)
            break
percentage_change_for_file2_leaf6=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_leaf6.append(((means_for_file2[6]-input_and_output_f2.leaf6.loc[i:j].mean())/means_for_file2[6])*100)
            break
percentage_change_for_file2_leaf7=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_leaf7.append(((means_for_file2[7]-input_and_output_f2.leaf7.loc[i:j].mean())/means_for_file2[7])*100)
            break
percentage_change_for_file2_leaf8=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_leaf8.append(((means_for_file2[8]-input_and_output_f2.leaf8.loc[i:j].mean())/means_for_file2[8])*100)
            break
percentage_change_for_file2_spine1=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_spine1.append(((means_for_file2[9]-input_and_output_f2.spine1.loc[i:j].mean())/means_for_file2[9])*100)
            break
percentage_change_for_file2_spine2=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_spine2.append(((means_for_file2[10]-input_and_output_f2.spine2.loc[i:j].mean())/means_for_file2[10])*100)
            break
percentage_change_for_file2_spine3=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_spine3.append(((means_for_file2[11]-input_and_output_f2.spine3.loc[i:j].mean())/means_for_file2[11])*100)
            break
percentage_change_for_file2_spine4=[0]
for i in input_and_output_f2.index[::400]:
    for j in input_and_output_f2.index:
        if j-i > 5000000000:
            percentage_change_for_file2_spine4.append(((means_for_file2[12]-input_and_output_f2.spine4.loc[i:j].mean())/means_for_file2[12])*100)
            break
percentage_change_for_file2=[percentage_change_for_file2_leaf1,percentage_change_for_file2_leaf2,percentage_change_for_file2_leaf3,percentage_change_for_file2_leaf4,percentage_change_for_file2_leaf5,percentage_change_for_file2_leaf6,percentage_change_for_file2_leaf7,percentage_change_for_file2_leaf8,percentage_change_for_file2_spine1,percentage_change_for_file2_spine2,percentage_change_for_file2_spine3,percentage_change_for_file2_spine4]

# %%
percentage_change_for_file1
# Out:
# [[0, leaf1    0.179512
#   dtype: float64, leaf1    0.19956
#   dtype: float64, leaf1    0.190305
#   dtype: float64, leaf1    0.212996
#   dtype: float64, leaf1    0.250136
#   dtype: float64, leaf1    0.258308
#   dtype: float64, leaf1    0.267152
#   dtype: float64, leaf1    0.256536
#   dtype: float64, leaf1    4.930341
#   dtype: float64, leaf1    5.424374
#   dtype: float64, leaf1    5.002463
#   dtype: float64, leaf1    3.242838
#   dtype: float64, leaf1    0.289276
#   dtype: float64, leaf1    0.252773
#   dtype: float64, leaf1    0.210387
#   dtype: float64, leaf1    5.275558
#   dtype: float64, leaf1    8.548549
#   dtype: float64, leaf1   -8.678883
#   dtype: float64, leaf1    10.932235
#   dtype: float64, leaf1    13.904157
#   dtype: float64, leaf1    5.36774
#   dtype: float64, leaf1    19.491106
#   dtype: float64, leaf1    16.106985
#   dtype: float64, leaf1    17.095763
#   dtype: float64, leaf1    17.972626
#   dtype: float64, leaf1    18.692541
# ...

# %%
percentage_change_for_file3
# Out:
# [[0, leaf1    0.203014
#   dtype: float64, leaf1    0.298521
#   dtype: float64, leaf1    0.441072
#   dtype: float64, leaf1    0.464953
#   dtype: float64, leaf1    3.266013
#   dtype: float64, leaf1    3.105374
#   dtype: float64, leaf1    3.250672
#   dtype: float64, leaf1    6.735121
#   dtype: float64, leaf1   -4.601297
#   dtype: float64, leaf1    3.018421
#   dtype: float64, leaf1    2.968486
#   dtype: float64, leaf1    2.937711
#   dtype: float64, leaf1    2.989231
#   dtype: float64, leaf1    3.27854
#   dtype: float64, leaf1    3.281082
#   dtype: float64, leaf1    0.333129
#   dtype: float64, leaf1    3.126032
#   dtype: float64, leaf1    3.060031
#   dtype: float64, leaf1    2.998042
#   dtype: float64, leaf1    2.923008
#   dtype: float64, leaf1    3.01938
#   dtype: float64, leaf1    3.073244
#   dtype: float64, leaf1    3.089505
#   dtype: float64, leaf1    4.570595
#   dtype: float64, leaf1    4.619217
#   dtype: float64, leaf1    1.020765
# ...

# %%
elements = ['No Failure','Leaf1','Leaf2','Leaf3','Leaf4','Leaf5','Leaf6','Leaf7','Leaf8','Spine1','Spine2','Spine3','Spine4']
probabilities = [0.5,1/24,1/24,1/24,1/24,1/24,1/24,1/24,1/24,1/24,1/24,1/24,1/24]

# %%
percentage_change_for_file2
# Out:
# [[0, leaf1    3.088051
#   dtype: float64, leaf1    4.50024
#   dtype: float64, leaf1    0.297238
#   dtype: float64, leaf1    0.140423
#   dtype: float64, leaf1    0.128503
#   dtype: float64, leaf1   -0.092961
#   dtype: float64, leaf1   -0.072462
#   dtype: float64, leaf1   -0.214128
#   dtype: float64, leaf1   -0.273788
#   dtype: float64, leaf1   -0.210181
#   dtype: float64, leaf1   -0.159386
#   dtype: float64, leaf1   -2.595126
#   dtype: float64, leaf1    4.630412
#   dtype: float64, leaf1    3.491628
#   dtype: float64, leaf1    5.36299
#   dtype: float64, leaf1    3.14398
#   dtype: float64, leaf1    5.192992
#   dtype: float64, leaf1    3.282609
#   dtype: float64, leaf1   -0.059489
#   dtype: float64, leaf1   -0.0243
#   dtype: float64, leaf1   -0.014406
#   dtype: float64, leaf1   -0.020102
#   dtype: float64, leaf1   -3.044905
#   dtype: float64, leaf1    3.551406
#   dtype: float64, leaf1    6.470289
#   dtype: float64, leaf1    2.318539
# ...

# %%
list1 = ['leaf1', 'leaf2', 'leaf3']
for leaf in list1:
    df = df[df['Producer'] = leaf]
